# %% [markdown]
# # Численное решение нелинейных уравнений

# %% [markdown]
# ## Setup:

# %%
import numpy as np
from numpy.polynomial.polynomial import Polynomial
import matplotlib.pyplot as plt

# %%
import rootapprox
from rootisol import sturms_method as sm
from rootisol import naive_method as rinm
from rootisol import binary_and_sturms_method as ribs
import extra

# %%
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# ***

# %% [markdown]
# ## Demo: метод Штурма

# %%
p = Polynomial([-1, 2, 3])

extra.latex_print(p)
xs = np.linspace(-1, 1, 64)
ys = p(xs)

plt.plot(xs, ys)
plt.show()

print(rinm.isolate_roots(p, -5, 5))
print(ribs.isolate_roots(p, -5, 5))
# Out:
# $\displaystyle 3.0x^{2}+2.0x-1.0$
# 2
# [(-1.0009999999999968, -0.9999999999999968), (0.33300000000000435, 0.33400000000000435)]
# [(-1.0003662109375, -0.999755859375), (0.333251953125, 0.3338623046875)]
